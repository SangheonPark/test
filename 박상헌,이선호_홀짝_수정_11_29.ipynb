# %%
import random
class Game:
  def __init__(self,name,m,a):
    #c:character, m:money, a:answer
    self.name=name
    self.m=m
    self.f_money = m
    self.a=a
    self.count = 0
    print(name,m,a)
  def makeA(self):
    self.right=random.randint(0,1);
  def uanswer(self):
    inta= 0 if self.a=='홀' else 1
    print('맞았습니다 ' if (self.right==inta) else '틀렸습니다.');
    print('정답은 홀 입니다.' if self.right==0 else '정답은 짝 입니다.')
    if self.right == inta:
      self.c= True 
    else :
      self.c = False
  def money_cal(self) : #4
    if self.c == True :
      self.m = self.m + self.m *1.5 

    else :
      self.m = self.m - self.m/2  
    print('당신의 현재돈은 {} 입니다'.format(self.m))

  def go_stop(self) : #5 # 초기에 설정한 돈보다 적어지면 게임이 스탑 
    
    self.count +=1
    if self.m < self.f_money :
      print('당신은 돈을 초기에 투자한 비용보다 잃었습니다. 게임을 종료합니다 \n 절망으로 치닫는 도박 중독의 위험, 지금 벗어나야 합니다. \n 도박문제 전화상담 1336 ') 
    
    else: 
      k = input('게임을 계속하시겠습니까?(yes/no)')
      if k== 'yes':
       return True
      else :
        return False 

  
  def inform(self) :
    print('이름 :{} \n 초기 투자비용 :{} \n 현재 가진 돈 :{} \n 게임횟수:{} ',format(self.name, self.f_money,self.m,self.count))
    
name= input('이름을 입력하시오.')
money= int(input('시작할 돈을 입력하시오 (범위 : 100~ 300사이)'))
choose= input('홀과 짝중 하나를선택하시오 게임이 시작됩니다')
instanceg=Game(name,money,choose)
instanceg.makeA()
instanceg.uanswer()
instanceg.money_cal()
instanceg.go_stop()
instanceg.go_stop()
# Out:
# 이름을 입력하시오.박상헌
# 시작할 돈을 입력하시오 (범위 : 100~ 300사이)100
# 홀과 짝중 하나를선택하시오 게임이 시작됩니다홀
# 박상헌 100 홀
# 맞았습니다
# 정답은 홀 입니다.
# 당신의 현재돈은 250.0 입니다
# 게임을 계속하시겠습니까?(yes/no)yes
# 게임을 계속하시겠습니까?(yes/no)yes
# True

# %%
import random
class Game:
  goal_money = 15000
  def __init__(self,name,m,a):
    #c:character, m:money, a:answer
    self.name=name
    self.m=m
    self.f_money = m
    self.a=a
    self.count = 0
    
  def makeA(self):
    self.right=random.randint(0,1);
  def uanswer(self):
    inta= 0 if self.a=='홀' else 1
    print('맞았습니다 ' if (self.right==inta) else '틀렸습니다.');
    print('정답은 홀 입니다.' if self.right==0 else '정답은 짝 입니다.')
    if self.right == inta:
      self.c= True 
    else :
      self.c = False
  def money_cal(self) : #4
    if self.c == True :
      self.m = self.m + self.m *1.5 

    else :
      self.m = self.m - self.m/2  
    print('당신의 현재돈은 {} 입니다'.format(self.m))
    return self.m

  def go_stop(self) : #5 # 초기에 설정한 돈보다 적어지면 게임이 스탑 
    
    
    if self.m < 90 :
      print('당신은 돈을 거의 잃었습니다. 게임을 종료합니다 \n 절망으로 치닫는 도박 중독의 위험, 지금 벗어나야 합니다. \n 도박문제 전화상담 1336 ')   
      return False 
    
    elif self.m == 15000 :
      print('당신은 목표한 금액에 달성하였습니다. 게임이 종료됩니다. ')
      

    elif self.m > 0 : 
      k = input('게임을 계속하시겠습니까?(yes/no)')
      if k== 'yes':
       return True
      else :
        print('게임을 종료합니다 \n 절망으로 치닫는 도박 중독의 위험, 지금 벗어나야 합니다. \n 도박문제 전화상담 1336 ')
        return False 

  
  def inform(self) :
    print('이름 :',self.name,'\n 현재 가진 돈 :',self.m)
  
name= input('이름을 입력하시오.')
c= int(input('시작할 돈을 입력하시오 (범위 : 100~ 300사이)'))
count = 0
print('당신은 목표 금액인 15000원을 달성해야 합니다.')
while True:
  count += 1 
  choose= input('홀과 짝중 하나를선택하시오 게임이 시작됩니다')
  instanceg=Game(name,c,choose)
  instanceg.inform()
  print('게임횟수:',count)

  instanceg.makeA()
  instanceg.uanswer()
  c = instanceg.money_cal()
  print('당신의 돈은 {}입니다 '.format(c))
  
  if instanceg.go_stop() == False :
    break
  else :
    continue
# Out:
# 이름을 입력하시오.박상헌
# 시작할 돈을 입력하시오 (범위 : 100~ 300사이)150
# 당신은 목표 금액인 15000원을 달성해야 합니다.
# 홀과 짝중 하나를선택하시오 게임이 시작됩니다홀
# 이름 : 박상헌
#  현재 가진 돈 : 150
# 게임횟수: 1
# 맞았습니다
# 정답은 홀 입니다.
# 당신의 현재돈은 375.0 입니다
# 당신의 돈은 375.0입니다
# 게임을 계속하시겠습니까?(yes/no)no
# 게임을 종료합니다
#  절망으로 치닫는 도박 중독의 위험, 지금 벗어나야 합니다.
#  도박문제 전화상담 1336

# %%
import random
class Game:
  right = ['홀','짝']
  c_money= [1000,2000]
  goal_money = 15000
  def __init__(self,name,m,a):
    #c:character, m:money, a:answer
    self.name=name
    self.m=m
    self.f_money = m
    self.a=a
    self.count = 0

  @staticmethod     # 스태틱 매소드 를사용하여 홀과 짝이 아닌경우 다시 하도록 함 . 
  def is_valid2(a):
    if a not in Game.right:
      print('홀과 짝중 선택해주세요' )
      return False
    else: 
      return True
    
    
  def makeA(self):
    self.right=random.randint(0,1);
  def uanswer(self):
    inta= 0 if self.a=='홀' else 1
    print('맞았습니다 ' if (self.right==inta) else '틀렸습니다.');
    print('정답은 홀 입니다.' if self.right==0 else '정답은 짝 입니다.')
    if self.right == inta:
      self.c= True 
    else :
      self.c = False
  def money_cal(self) : #4
    if self.c == True :
      self.m = self.m + self.m *1.5 

    else :
      self.m = self.m - self.m/2  
    print('당신의 현재돈은 {} 입니다'.format(self.m))
    return self.m

  def go_stop(self) : #5 # 초기에 설정한 돈보다 적어지면 게임이 스탑 
    
    
    if self.m < 900 :
      print('당신은 돈을 거의 잃었습니다. 게임을 종료합니다 \n 절망으로 치닫는 도박 중독의 위험, 지금 벗어나야 합니다. \n 도박문제 전화상담 1336 ')   
      return False 
    
    elif self.m == 15000 :
      print('당신은 목표한 금액에 달성하였습니다. 게임이 종료됩니다. ')
      

    elif self.m > 0 : 
      k = input('게임을 계속하시겠습니까?(yes/no)')
      if k== 'yes':
       return True
      else :
        print('게임을 종료합니다 \n 절망으로 치닫는 도박 중독의 위험, 지금 벗어나야 합니다. \n 도박문제 전화상담 1336 ')
        return False 

  
  def inform(self) : # 정보 
    print('이름 :',self.name,'\n 현재 가진 돈 :',self.m)
  
name= input('이름을 입력하시오.')
c= int(input('시작할 돈을 입력하시오 ( 1000원과 2000원 중 선택하시오.)'))
count = 0
print('당신은 목표 금액인 15000원을 달성해야 합니다.')
while True:
  count += 1 
  choose= input('홀과 짝중 하나를선택하시오 게임이 시작됩니다')
  

  instanceg=Game(name,c,choose)
  
  while instanceg.is_valid2(choose)== False:
      choose= input('홀과 짝중 하나를선택하시오 게임이 시작됩니다')
  instanceg.inform()
  print('게임횟수:',count)

  instanceg.makeA()
  instanceg.uanswer()
  c = instanceg.money_cal()
  print('당신의 돈은 {}입니다 '.format(c))
  
  if instanceg.go_stop() == False :
    break
  else :
    continue
# Out:
# 이름을 입력하시오.박상헌
# 시작할 돈을 입력하시오 ( 1000원과 2000원 중 선택하시오.)1000
# 당신은 목표 금액인 15000원을 달성해야 합니다.
# 홀과 짝중 하나를선택하시오 게임이 시작됩니다홀
# 이름 : 박상헌
#  현재 가진 돈 : 1000
# 게임횟수: 1
# 틀렸습니다.
# 정답은 짝 입니다.
# 당신의 현재돈은 500.0 입니다
# 당신의 돈은 500.0입니다
# 당신은 돈을 거의 잃었습니다. 게임을 종료합니다
#  절망으로 치닫는 도박 중독의 위험, 지금 벗어나야 합니다.
#  도박문제 전화상담 1336

# %%
#완성본  # try -except 문 추가 하기 
import random
class Game:
  right = ['홀','짝']
  c_money= [1000,2000]
  goal_money = 15000
  count = 0 
  def __init__(self,name,m,a):
    #c:character, m:money, a:answer
    Game.count += 1
    self.name=name
    self.m=m
    self.f_money = m
    self.a=a
    

  @staticmethod     # 스태틱 매소드 를사용하여 홀과 짝이 아닌경우 다시 하도록 함 . 
  def is_valid2(a):
    if a not in Game.right:
      print('홀과 짝중 선택해주세요' )
      return False
    else: 
      return True
    
    
  def makeA(self):
    self.right=random.randint(0,1);
  def uanswer(self):
    inta= 0 if self.a=='홀' else 1
    print('맞았습니다 ' if (self.right==inta) else '틀렸습니다.');
    print('정답은 홀 입니다.' if self.right==0 else '정답은 짝 입니다.')
    if self.right == inta:
      self.c= True 
    else :
      self.c = False
  def money_cal(self) : #4
    if self.c == True :
      self.m = self.m + self.m *1.5 

    else :
      self.m = self.m - self.m/2  
    print('당신의 현재돈은 {} 입니다'.format(self.m))
    return self.m

  def go_stop(self) : #5 # 초기에 설정한 돈보다 적어지면 게임이 스탑 
    
    
    if self.m < 900 :
      print('당신은 돈을 거의 잃었습니다. 게임을 종료합니다 \n 절망으로 치닫는 도박 중독의 위험, 지금 벗어나야 합니다. \n 도박문제 전화상담 1336 ')   
      return False 
    
    elif self.m == 15000 :
      print('당신은 목표한 금액에 달성하였습니다. 게임이 종료됩니다. ')
      

    elif self.m > 0 : 
      k = input('게임을 계속하시겠습니까?(yes/no)')
      if k== 'yes':
       return True
      else :
        print('게임을 종료합니다 \n 절망으로 치닫는 도박 중독의 위험, 지금 벗어나야 합니다. \n 도박문제 전화상담 1336 ')
        return False 

  @classmethod
  def inform(cls) : # 정보 
    print('게임 횟수:',cls.count)

  def inform2(self) : # 정보 
    print('이름 :',self.name,'\n현재 가진 돈 :',self.m)
    
    
  
name= input('이름을 입력하시오.')
c= int(input('시작할 돈을 입력하시오 ( 1000원과 2000원 중 선택하시오.)'))
count = 0
print('당신은 목표 금액인 15000원을 달성해야 합니다.')
while True:
  count += 1 
  choose= input('홀과 짝중 하나를선택하시오 게임이 시작됩니다')
  

  instanceg=Game(name,c,choose)
  
  while instanceg.is_valid2(choose)== False:
      choose= input('홀과 짝중 하나를선택하시오 게임이 시작됩니다')
  instanceg.inform()
  instanceg.inform2()

  instanceg.makeA()
  instanceg.uanswer()
  c = instanceg.money_cal()
  print('당신의 돈은 {}입니다 '.format(c))
  
  if instanceg.go_stop() == False :
    break
  else :
    continue
# Out:
# 이름을 입력하시오.박상헌
# 시작할 돈을 입력하시오 ( 1000원과 2000원 중 선택하시오.)1000
# 당신은 목표 금액인 15000원을 달성해야 합니다.
# 홀과 짝중 하나를선택하시오 게임이 시작됩니다홀
# 게임 횟수: 1
# 이름 : 박상헌
# 현재 가진 돈 : 1000
# 맞았습니다
# 정답은 홀 입니다.
# 당신의 현재돈은 2500.0 입니다
# 당신의 돈은 2500.0입니다
# 게임을 계속하시겠습니까?(yes/no)yes
# 홀과 짝중 하나를선택하시오 게임이 시작됩니다짝
# 게임 횟수: 2
# 이름 : 박상헌
# 현재 가진 돈 : 2500.0
# 맞았습니다
# 정답은 짝 입니다.
# 당신의 현재돈은 6250.0 입니다
# 당신의 돈은 6250.0입니다
# 게임을 계속하시겠습니까?(yes/no)yes
# 게임을 종료합니다
#  절망으로 치닫는 도박 중독의 위험, 지금 벗어나야 합니다.
#  도박문제 전화상담 1336

# %%
import random
class Game:
  right = ['홀','짝']
  c_money= [1000,2000]
  goal_money = 15000
  count = 0 
  def __init__(self,name,m,a):
    #c:character, m:money, a:answer
    Game.count += 1
    self.name=name
    self.m=m
    self.f_money = m
    self.a=a
    

  @staticmethod     # 스태틱 매소드 를사용하여 홀과 짝이 아닌경우 다시 하도록 함 . 
  def is_valid2(a):
    if a not in Game.right:
      print('홀과 짝중 선택해주세요' )
      return False
    else: 
      return True
    
    
  def makeA(self):
    self.right=random.randint(0,1);
  def uanswer(self):
    inta= 0 if self.a=='홀' else 1
    print('맞았습니다 ' if (self.right==inta) else '틀렸습니다.');
    print('정답은 홀 입니다.' if self.right==0 else '정답은 짝 입니다.')
    if self.right == inta:
      self.c= True 
    else :
      self.c = False
  def money_cal(self) : #4
    if self.c == True :
      self.m = self.m + self.m *1.5 

    else :
      self.m = self.m - self.m/2  
    print('당신의 현재돈은 {} 입니다'.format(self.m))
    return self.m

  def go_stop(self) : #5 # 초기에 설정한 돈보다 적어지면 게임이 스탑 
    
    
    if self.m < 900 :
      print('당신은 돈을 거의 잃었습니다. 게임을 종료합니다 \n 절망으로 치닫는 도박 중독의 위험, 지금 벗어나야 합니다. \n 도박문제 전화상담 1336 ')   
      return False 
    
    elif self.m == 15000 :
      print('당신은 목표한 금액에 달성하였습니다. 게임이 종료됩니다. ')
      

    elif self.m > 0 : 
      k = input('게임을 계속하시겠습니까?(yes/no)')
      if k== 'yes':
       return True
      else :
        print('게임을 종료합니다 \n 절망으로 치닫는 도박 중독의 위험, 지금 벗어나야 합니다. \n 도박문제 전화상담 1336 ')
        return False 

  @classmethod
  def inform(cls) : # 정보 
    print('게임 횟수:',cls.count)

  def inform2(self) : # 정보 
    print('이름 :',self.name,'\n현재 가진 돈 :',self.m)
    
    
  
name= input('이름을 입력하시오.')
c= int(input('시작할 돈을 입력하시오 ( 1000원과 2000원 중 선택하시오.)'))
count = 0
print('당신은 목표 금액인 15000원을 달성해야 합니다.')
while True:
  count += 1 
  choose= input('홀과 짝중 하나를선택하시오 게임이 시작됩니다')
  

  instanceg=Game(name,c,choose)
  
  while instanceg.is_valid2(choose)== False:
      choose= input('홀과 짝중 하나를선택하시오 게임이 시작됩니다')
  instanceg.inform()
  instanceg.inform2()

  instanceg.makeA()
  instanceg.uanswer()
  c = instanceg.money_cal()
  print('당신의 돈은 {}입니다 '.format(c))
  
  if instanceg.go_stop() == False :
    break
  else :
    continue

# %%
from re import T
import random
class Game:
  right = ['홀','짝']
  
  goal_money = 15000
  count = 0 
  def __init__(self,name,m,a):
    #c:character, m:money, a:answer
    Game.count += 1
    self.name=name
    self.m=m
    self.f_money = m
    self.a=a

  @staticmethod     # 스태틱 매소드 를사용하여 홀과 짝이 아닌경우 다시 하도록 함 . 
  def is_valid2(a):
    if a not in Game.right:
      print('홀과 짝중 선택해주세요' )
      return False
    else: 
      return True

  def is_valid(c):
    ll = ['cat','dog']
    while True:
      try: 
        

        if c in ll:
              return True
        else:
            input('다시 입력하시오.')
            
      except:
            input('다시 입력하시오')


    
    
  def makeA(self):
    self.right=random.randint(0,1);
  def uanswer(self):
    inta= 0 if self.a=='홀' else 1
    print('맞았습니다 ' if (self.right==inta) else '틀렸습니다.');
    print('정답은 홀 입니다.' if self.right==0 else '정답은 짝 입니다.')
    if self.right == inta:
      self.c= True 
    else :
      self.c = False
  def money_cal(self) : #4
    if self.c == True :
      self.m = self.m + self.m *1.5 

    else :
      self.m = self.m - self.m/2  
    print('당신의 현재돈은 {} 입니다'.format(self.m))
    return self.m

  def go_stop(self) : #5 # 초기에 설정한 돈보다 적어지면 게임이 스탑 
    
    
    if self.m < 900 :
      print('당신은 돈을 거의 잃었습니다. 게임을 종료합니다 \n 절망으로 치닫는 도박 중독의 위험, 지금 벗어나야 합니다. \n 도박문제 전화상담 1336 ')   
      return False 
    
    elif self.m >= 15000 :
      print('당신은 목표한 금액에 달성하였습니다. 게임이 종료됩니다. ')
      return False
      

    elif self.m > 0 : 
      k = input('게임을 계속하시겠습니까?(yes/no)')
      if k== 'yes':
       return True
      else :
        print('게임을 종료합니다 \n 절망으로 치닫는 도박 중독의 위험, 지금 벗어나야 합니다. \n 도박문제 전화상담 1336 ')
        return False 

  @classmethod
  def inform(cls) : # 정보 
    print('게임 횟수:',cls.count)

  def inform2(self) : # 정보 
    print('이름 :',self.name,'\n현재 가진 돈 :',self.m)
          
    
    
ll = ['cat','dog']
k = random.randint(0,2)
t= ll[k]
pp= input('당신이 로봇이 아님을 증명하시오.\n {}를 똑같이 입력하시오'.format(t))
Game.is_valid(pp)
name= input('이름을 입력하시오.')

c= int(input('시작할 돈을 입력하시오'))

count = 0

while True:
  
  count += 1 
  choose= input('홀과 짝중 하나를선택하시오 게임이 시작됩니다')

  instanceg=Game(name,c,choose)
  
  while instanceg.is_valid2(choose)== False:
      choose= input('홀과 짝중 하나를선택하시오 게임이 시작됩니다')
  instanceg.inform()
  instanceg.inform2()

  instanceg.makeA()
  instanceg.uanswer()
  c = instanceg.money_cal()
  print('당신의 돈은 {}입니다 '.format(c))
  
  if instanceg.go_stop() == False :
    break
  else :
    continue
# Out:
# 당신이 로봇이 아님을 증명하시오.
#  cat를 똑같이 입력하시오cat
# 이름을 입력하시오.qkr
# 시작할 돈을 입력하시오1040
# 홀과 짝중 하나를선택하시오 게임이 시작됩니다홀
# 게임 횟수: 1
# 이름 : qkr
# 현재 가진 돈 : 1040
# 맞았습니다
# 정답은 홀 입니다.
# 당신의 현재돈은 2600.0 입니다
# 당신의 돈은 2600.0입니다
# 게임을 계속하시겠습니까?(yes/no)no
# 게임을 종료합니다
#  절망으로 치닫는 도박 중독의 위험, 지금 벗어나야 합니다.
#  도박문제 전화상담 1336
